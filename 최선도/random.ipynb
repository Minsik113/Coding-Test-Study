# %%
import random

name_list = ['정진', '이진웅', '이해현', '성미래', '윤혜영', '장윤식', '조민식', '최선도']

k = int(input())

for i in range(k):
    random.shuffle(name_list)
    
    if i==k-1:
        print(f"최종 : {name_list}")
    else:
        print(f'{i} 번째: {name_list}')
# Out:
# 0 번째: ['성미래', '정진', '윤혜영', '장윤식', '이진웅', '조민식', '최선도', '이해현']
# 1 번째: ['장윤식', '조민식', '윤혜영', '정진', '최선도', '이진웅', '성미래', '이해현']
# 2 번째: ['이해현', '윤혜영', '최선도', '이진웅', '장윤식', '조민식', '성미래', '정진']
# 3 번째: ['성미래', '최선도', '이해현', '이진웅', '윤혜영', '조민식', '장윤식', '정진']
# 4 번째: ['성미래', '최선도', '이진웅', '장윤식', '윤혜영', '조민식', '이해현', '정진']
# 5 번째: ['정진', '조민식', '이진웅', '성미래', '장윤식', '최선도', '이해현', '윤혜영']
# 6 번째: ['정진', '성미래', '이해현', '윤혜영', '이진웅', '장윤식', '조민식', '최선도']
# 7 번째: ['이진웅', '이해현', '윤혜영', '조민식', '정진', '장윤식', '최선도', '성미래']
# 8 번째: ['성미래', '조민식', '이해현', '정진', '윤혜영', '장윤식', '이진웅', '최선도']
# 9 번째: ['정진', '최선도', '성미래', '이진웅', '조민식', '장윤식', '윤혜영', '이해현']
# 10 번째: ['최선도', '장윤식', '이해현', '성미래', '이진웅', '윤혜영', '정진', '조민식']
# 11 번째: ['장윤식', '이진웅', '윤혜영', '이해현', '최선도', '조민식', '정진', '성미래']
# 12 번째: ['윤혜영', '정진', '성미래', '이해현', '최선도', '이진웅', '조민식', '장윤식']
# 13 번째: ['이진웅', '조민식', '윤혜영', '성미래', '이해현', '정진', '장윤식', '최선도']
# 14 번째: ['이진웅', '이해현', '장윤식', '최선도', '성미래', '정진', '윤혜영', '조민식']
# ...
